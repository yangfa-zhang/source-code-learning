# %% [markdown]
# symbolic regression: feyn library

# %%
import feyn

ql = feyn.QLattice()
# Out:
# This version of Feyn and the QLattice is available for academic, personal, and non-commercial use. By using the community version of this software you agree to the terms and conditions which can be found at https://abzu.ai/eula.

# %%
from feyn.datasets import make_classification

train, test = make_classification()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75 entries, 30 to 2
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x0      75 non-null     float64
#  1   x1      75 non-null     float64
#  2   x2      75 non-null     float64
#  3   x3      75 non-null     float64
#  4   x4      75 non-null     float64
#  5   x5      75 non-null     float64
#  6   x6      75 non-null     float64
#  7   x7      75 non-null     float64
#  8   x8      75 non-null     float64
#  9   x9      75 non-null     float64
#  10  x10     75 non-null     float64
#  11  x11     75 non-null     float64
#  12  x12     75 non-null     float64
#  13  x13     75 non-null     float64
#  14  x14     75 non-null     float64
#  15  x15     75 non-null     float64
#  16  x16     75 non-null     float64
#  17  x17     75 non-null     float64
#  18  x18     75 non-null     float64
#  19  x19     75 non-null     float64
#  20  y       75 non-null     int32
# ...

# %%
models = ql.auto_run(train, output_name = 'y', kind = 'classification')
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <svg baseProfile="full" height="160.0" preserveAspectRatio="none" version="1.1" viewBox="0 0 471 160.0" width="471" xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs /><svg class="graph" height="155.0" width="471" x="0" y="0"><defs /><text fill="#1E1E1E" font-family="monospace" font-size="12" text-anchor="middle" x="406.0" y="99.0">Loss: 2.84E-01</text><text fill="#1E1E1E" font-family="monospace" font-size="12" text-anchor="start" x="0" y="145.0">Epoch no. 10/10 - Tried 11350 models - Completed in 22s.</text><rect class="node" fill="#00F082" height="35" stroke="#1E1E1E" stroke-width="1" width="90" x="361" y="50.0"><title>y
# logistic:
# w=-2.9114
# ...

# %%
best = models[0]
best.plot(train, test)
best.plot_roc_curve(test)
